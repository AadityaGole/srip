# %%
import json
import networkx as nx
from networkx.algorithms.simple_paths import shortest_simple_paths


with open("cable-and-landing-points.json", "r") as cable_and_landing_points_file:
    cable_and_landing_points = json.load(cable_and_landing_points_file)

# %%
allowed_countries = {
    "India", "Australia", "Sri Lanka", "Myanmar", "Thailand", "Cambodia",
    "Vietnam", "Malaysia", "Indonesia", "Singapore", "Papua New Guinea",
    "Brunei", "Timor-Leste", "Philippines", "Solomon Islands"
}

def normalize_node(landing_point):
    return f"{landing_point['city'].strip()}, {landing_point['country'].strip()}"

def get_coords(landing_point):
    return tuple(landing_point["coordinates"])

G = nx.Graph()
node_coords = {} 
india_nodes = set()
australia_nodes = set()
allowed_nodes = set()

for cable in cable_and_landing_points:
    points = cable["landing_points"]
    
    for i in range(len(points)):
        node_i = normalize_node(points[i])
        coord_i = get_coords(points[i])
        country_i = points[i]['country']

        node_coords[node_i] = coord_i

        if country_i == "India":
            india_nodes.add(node_i)
        elif country_i == "Australia":
            australia_nodes.add(node_i)
        if country_i in allowed_countries:
            allowed_nodes.add(node_i)

        for j in range(i + 1, len(points)):
            node_j = normalize_node(points[j])
            coord_j = get_coords(points[j])
            country_j = points[j]['country']

            node_coords[node_j] = coord_j
            if country_j in allowed_countries:
                allowed_nodes.add(node_j)

            # Only add edge if it's between different countries
            if country_i != country_j:
                G.add_edge(node_i, node_j, cable=cable["cable_name"])


subG = G.subgraph(allowed_nodes)

def is_valid_path(path):
    return all(node in allowed_nodes for node in path)

MAX_PATHS_PER_PAIR = 10
all_valid_paths = []

# Keep only nodes that are present in the subgraph
india_nodes = india_nodes & set(subG.nodes)
australia_nodes = australia_nodes & set(subG.nodes)


for source in india_nodes:
    for target in australia_nodes:
        try:
            path_gen = shortest_simple_paths(subG, source, target)
            count = 0
            for path in path_gen:
                if count >= MAX_PATHS_PER_PAIR:
                    break
                if is_valid_path(path):
        
                    cables = []
                    for i in range(len(path) - 1):
                        edge_data = subG.get_edge_data(path[i], path[i+1])
                        if edge_data:
                            cables.append(edge_data.get("cable"))
                    all_valid_paths.append({
                        "path": path,
                        "cables": cables
                    })
                    count += 1
        except nx.NetworkXNoPath:
            continue

geojson_features = []

for item in all_valid_paths:
    path = item["path"]
    cables = item["cables"]
    coordinates = [node_coords[node] for node in path]

    feature = {
        "type": "Feature",
        "properties": {
            "path": path,
            "cables": cables
        },
        "geometry": {
            "type": "LineString",
            "coordinates": coordinates
        }
    }
    geojson_features.append(feature)

geojson_output = {
    "type": "FeatureCollection",
    "features": geojson_features
}

with open("india_australia_paths.geojson", "w") as f:
    json.dump(geojson_output, f, indent=2)
no_domestic_hops_features = []

for item in all_valid_paths:
    path = item["path"]
    cables = item["cables"]
    coordinates = [node_coords[node] for node in path]

    # Initialize fault counts (replace with actual fault data if available)
    fault_counts = {cable: 0 for cable in cables}

    feature = {
        "type": "Feature",
        "properties": {
            "path": path,
            "cables": cables,
            "cable_count": len(cables),
            "fault_counts": fault_counts
        },
        "geometry": {
            "type": "LineString",
            "coordinates": coordinates
        }
    }

    no_domestic_hops_features.append(feature)

# Wrap in a FeatureCollection
no_domestic_hops_geojson = {
    "type": "FeatureCollection",
    "features": no_domestic_hops_features
}

# Save to file
with open("no_domestic_hops.json", "w") as f:
    json.dump(no_domestic_hops_geojson, f, indent=2)

for item in all_valid_paths:
    print(" → ".join(item["path"]))
    print("  Cables:", " → ".join(item["cables"]))
    print()
# Out:
# Kochi, India → Jakarta, Indonesia → Sydney, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Singapore, Singapore → Sydney, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Sydney, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Port Moresby, Papua New Guinea → Sydney, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Kochi, India → Singapore, Singapore → Batam, Indonesia → Sydney, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Port Moresby, Papua New Guinea → Sydney, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Kochi, India → Jakarta, Indonesia → Honiara, Solomon Islands → Sydney, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Kochi, India → Singapore, Singapore → Port Moresby, Papua New Guinea → Sydney, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Kochi, India → Ancol, Indonesia → Honiara, Solomon Islands → Sydney, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Kochi, India → Jakarta, Indonesia → Singapore, Singapore → Sydney, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Brisbane, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Singapore, Singapore → Brisbane, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Brisbane, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Port Moresby, Papua New Guinea → Brisbane, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Singapore, Singapore → Batam, Indonesia → Brisbane, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Port Moresby, Papua New Guinea → Brisbane, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Honiara, Solomon Islands → Brisbane, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Singapore, Singapore → Port Moresby, Papua New Guinea → Brisbane, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Honiara, Solomon Islands → Brisbane, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Singapore, Singapore → Brisbane, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Perth, Australia
#   Cables: ICE IV → INDIGO-West
#
# Kochi, India → Ancol, Indonesia → Perth, Australia
#   Cables: ICE IV → INDIGO-West
#
# Kochi, India → Jakarta, Indonesia → Tuas, Singapore → Perth, Australia
#   Cables: ICE IV → Indonesia Global Gateway (IGG) System → INDIGO-West
#
# Kochi, India → Singapore, Singapore → Jakarta, Indonesia → Perth, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → INDIGO-West
#
# Kochi, India → Ancol, Indonesia → Tuas, Singapore → Perth, Australia
#   Cables: ICE IV → Indonesia Global Gateway (IGG) System → INDIGO-West
#
# Kochi, India → Jakarta, Indonesia → Tanah Merah, Singapore → Perth, Australia
#   Cables: ICE IV → Jakarta-Bangka-Bintan-Batam-Singapore (B3JS) → Australia-Singapore Cable (ASC)
#
# Kochi, India → Singapore, Singapore → Ancol, Indonesia → Perth, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → INDIGO-West
#
# Kochi, India → Ancol, Indonesia → Tanah Merah, Singapore → Perth, Australia
#   Cables: ICE IV → Jakarta-Bangka-Bintan-Batam-Singapore (B3JS) → Australia-Singapore Cable (ASC)
#
# Kochi, India → Jakarta, Indonesia → Tuas, Singapore → Ancol, Indonesia → Perth, Australia
#   Cables: ICE IV → Indonesia Global Gateway (IGG) System → Indonesia Global Gateway (IGG) System → INDIGO-West
#
# Kochi, India → Penang, Malaysia → Songkhla, Thailand → Tuas, Singapore → Perth, Australia
#   Cables: SAFE → Asia Africa Europe-1 (AAE-1) → SEA-H2X → INDIGO-West
#
# Kochi, India → Jakarta, Indonesia → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Singapore, Singapore → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Port Moresby, Papua New Guinea → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Singapore, Singapore → Batam, Indonesia → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Port Moresby, Papua New Guinea → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Honiara, Solomon Islands → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Singapore, Singapore → Port Moresby, Papua New Guinea → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Honiara, Solomon Islands → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Singapore, Singapore → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Singapore, Singapore → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Davao, Philippines → Darwin, Australia
#   Cables: ICE IV → Bifrost → Asia Connect Cable-1 (ACC-1)
#
# Kochi, India → Singapore, Singapore → Batam, Indonesia → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Davao, Philippines → Darwin, Australia
#   Cables: ICE IV → Bifrost → Asia Connect Cable-1 (ACC-1)
#
# Kochi, India → Jakarta, Indonesia → Singapore, Singapore → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Singapore, Singapore → Makassar, Indonesia → Darwin, Australia
#   Cables: ICE IV → Asia Connect Cable-1 (ACC-1) → Asia Connect Cable-1 (ACC-1)
#
# Kochi, India → Ancol, Indonesia → Singapore, Singapore → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Dili, Timor-Leste → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Singapore, Singapore → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Kochi, India → Jakarta, Indonesia → Port Moresby, Papua New Guinea → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Kochi, India → Singapore, Singapore → Batam, Indonesia → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Kochi, India → Ancol, Indonesia → Port Moresby, Papua New Guinea → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Kochi, India → Jakarta, Indonesia → Honiara, Solomon Islands → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Kochi, India → Singapore, Singapore → Port Moresby, Papua New Guinea → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Kochi, India → Ancol, Indonesia → Honiara, Solomon Islands → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Kochi, India → Jakarta, Indonesia → Singapore, Singapore → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Tanjung Bemban, Indonesia → Sydney, Australia
#   Cables: FALCON → SeaMeWe-4 → Apricot → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Melaka, Malaysia → Batam, Indonesia → Sydney, Australia
#   Cables: FALCON → SeaMeWe-4 → Batam Dumai Melaka (BDM) → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Batam, Indonesia → Sydney, Australia
#   Cables: FALCON → SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Chennai, India → Jakarta, Indonesia → Sydney, Australia
#   Cables: FALCON → SeaMeWe-4 → ICE IV → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Melaka, Malaysia → Tanjung Pinggir, Indonesia → Sydney, Australia
#   Cables: FALCON → SeaMeWe-4 → Batam Dumai Melaka (BDM) → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Jakarta, Indonesia → Sydney, Australia
#   Cables: FALCON → SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Chennai, India → Singapore, Singapore → Sydney, Australia
#   Cables: FALCON → SeaMeWe-4 → ICE IV → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Tanjung Pinggir, Indonesia → Sydney, Australia
#   Cables: FALCON → SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Chennai, India → Ancol, Indonesia → Sydney, Australia
#   Cables: FALCON → SeaMeWe-4 → ICE IV → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Ancol, Indonesia → Sydney, Australia
#   Cables: FALCON → SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Tanjung Bemban, Indonesia → Brisbane, Australia
#   Cables: FALCON → SeaMeWe-4 → Apricot → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Melaka, Malaysia → Batam, Indonesia → Brisbane, Australia
#   Cables: FALCON → SeaMeWe-4 → Batam Dumai Melaka (BDM) → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Batam, Indonesia → Brisbane, Australia
#   Cables: FALCON → SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Chennai, India → Jakarta, Indonesia → Brisbane, Australia
#   Cables: FALCON → SeaMeWe-4 → ICE IV → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Melaka, Malaysia → Tanjung Pinggir, Indonesia → Brisbane, Australia
#   Cables: FALCON → SeaMeWe-4 → Batam Dumai Melaka (BDM) → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Jakarta, Indonesia → Brisbane, Australia
#   Cables: FALCON → SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Chennai, India → Singapore, Singapore → Brisbane, Australia
#   Cables: FALCON → SeaMeWe-4 → ICE IV → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Tanjung Pinggir, Indonesia → Brisbane, Australia
#   Cables: FALCON → SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Chennai, India → Ancol, Indonesia → Brisbane, Australia
#   Cables: FALCON → SeaMeWe-4 → ICE IV → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Ancol, Indonesia → Brisbane, Australia
#   Cables: FALCON → SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Perth, Australia
#   Cables: FALCON → SeaMeWe-4 → INDIGO-West
#
# Trivandrum, India → Colombo, Sri Lanka → Mumbai, India → Tuas, Singapore → Perth, Australia
#   Cables: FALCON → FALCON → SeaMeWe-4 → INDIGO-West
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Jakarta, Indonesia → Perth, Australia
#   Cables: FALCON → SeaMeWe-4 → Indonesia Global Gateway (IGG) System → INDIGO-West
#
# Trivandrum, India → Colombo, Sri Lanka → Satun, Thailand → Tuas, Singapore → Perth, Australia
#   Cables: FALCON → SeaMeWe-4 → SeaMeWe-4 → INDIGO-West
#
# Trivandrum, India → Colombo, Sri Lanka → Tuas, Singapore → Ancol, Indonesia → Perth, Australia
#   Cables: FALCON → SeaMeWe-4 → Indonesia Global Gateway (IGG) System → INDIGO-West
#
# Trivandrum, India → Colombo, Sri Lanka → Melaka, Malaysia → Tuas, Singapore → Perth, Australia
#   Cables: FALCON → SeaMeWe-4 → SeaMeWe-5 → INDIGO-West
#
# Trivandrum, India → Colombo, Sri Lanka → Chennai, India → Tuas, Singapore → Perth, Australia
#   Cables: FALCON → SeaMeWe-4 → SeaMeWe-4 → INDIGO-West
#
# Trivandrum, India → Colombo, Sri Lanka → Chennai, India → Jakarta, Indonesia → Perth, Australia
#   Cables: FALCON → SeaMeWe-4 → ICE IV → INDIGO-West
#
# Trivandrum, India → Colombo, Sri Lanka → Chennai, India → Ancol, Indonesia → Perth, Australia
#   Cables: FALCON → SeaMeWe-4 → ICE IV
Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → Thailand-Indonesia-Singapore (TIS) → Hawaiki Nui 1
#
# Mumbai, India → Tuas, Singapore → Tanjung Pinggir, Indonesia → Brisbane, Australia
#   Cables: SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Mumbai, India → Vung Tau, Vietnam → Tanjung Bemban, Indonesia → Brisbane, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → Asia-America Gateway (AAG) Cable System → Hawaiki Nui 1
#
# Mumbai, India → Melaka, Malaysia → Tanjung Pinggir, Indonesia → Brisbane, Australia
#   Cables: SeaMeWe-4 → Batam Dumai Melaka (BDM) → Hawaiki Nui 1
#
# Mumbai, India → Songkhla, Thailand → Tanjung Bemban, Indonesia → Brisbane, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → SEA-H2X → Hawaiki Nui 1
#
# Mumbai, India → Tuas, Singapore → Tanjung Bemban, Indonesia → Brisbane, Australia
#   Cables: SeaMeWe-4 → Apricot → Hawaiki Nui 1
#
# Mumbai, India → Tuas, Singapore → Perth, Australia
#   Cables: SeaMeWe-4 → INDIGO-West
#
# Mumbai, India → Songkhla, Thailand → Tuas, Singapore → Perth, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → SEA-H2X → INDIGO-West
#
# Mumbai, India → Tuas, Singapore → Jakarta, Indonesia → Perth, Australia
#   Cables: SeaMeWe-4 → Indonesia Global Gateway (IGG) System → INDIGO-West
#
# Mumbai, India → Matara, Sri Lanka → Tuas, Singapore → Perth, Australia
#   Cables: India Asia Xpress (IAX) → SeaMeWe-5 → INDIGO-West
#
# Mumbai, India → Tuas, Singapore → Ancol, Indonesia → Perth, Australia
#   Cables: SeaMeWe-4 → Indonesia Global Gateway (IGG) System → INDIGO-West
#
# Mumbai, India → Morib, Malaysia → Tuas, Singapore → Perth, Australia
#   Cables: MIST → MIST → INDIGO-West
#
# Mumbai, India → Satun, Thailand → Tuas, Singapore → Perth, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → SeaMeWe-4 → INDIGO-West
#
# Mumbai, India → Colombo, Sri Lanka → Tuas, Singapore → Perth, Australia
#   Cables: FALCON → SeaMeWe-4 → INDIGO-West
#
# Mumbai, India → Melaka, Malaysia → Tuas, Singapore → Perth, Australia
#   Cables: SeaMeWe-4 → SeaMeWe-5 → INDIGO-West
#
# Mumbai, India → Ngwe Saung, Myanmar → Tuas, Singapore → Perth, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → SeaMeWe-5 → INDIGO-West
#
# Mumbai, India → Tuas, Singapore → Batam, Indonesia → Alexandria, Australia
#   Cables: SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Mumbai, India → Songkhla, Thailand → Batam, Indonesia → Alexandria, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → Thailand-Indonesia-Singapore (TIS) → Hawaiki Nui 1
#
# Mumbai, India → Tuas, Singapore → Jakarta, Indonesia → Alexandria, Australia
#   Cables: SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Mumbai, India → Melaka, Malaysia → Batam, Indonesia → Alexandria, Australia
#   Cables: SeaMeWe-4 → Batam Dumai Melaka (BDM) → Hawaiki Nui 1
#
# Mumbai, India → Songkhla, Thailand → Tanjung Pinggir, Indonesia → Alexandria, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → Thailand-Indonesia-Singapore (TIS) → Hawaiki Nui 1
#
# Mumbai, India → Tuas, Singapore → Tanjung Pinggir, Indonesia → Alexandria, Australia
#   Cables: SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Mumbai, India → Vung Tau, Vietnam → Tanjung Bemban, Indonesia → Alexandria, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → Asia-America Gateway (AAG) Cable System → Hawaiki Nui 1
#
# Mumbai, India → Melaka, Malaysia → Tanjung Pinggir, Indonesia → Alexandria, Australia
#   Cables: SeaMeWe-4 → Batam Dumai Melaka (BDM) → Hawaiki Nui 1
#
# Mumbai, India → Songkhla, Thailand → Tanjung Bemban, Indonesia → Alexandria, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → SEA-H2X → Hawaiki Nui 1
#
# Mumbai, India → Tuas, Singapore → Tanjung Bemban, Indonesia → Alexandria, Australia
#   Cables: SeaMeWe-4 → Apricot → Hawaiki Nui 1
#
# Mumbai, India → Tuas, Singapore → Batam, Indonesia → Darwin, Australia
#   Cables: SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Mumbai, India → Songkhla, Thailand → Tanjung Bemban, Indonesia → Darwin, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → SEA-H2X → Hawaiki Nui 1
#
# Mumbai, India → Tuas, Singapore → Makassar, Indonesia → Darwin, Australia
#   Cables: SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Asia Connect Cable-1 (ACC-1)
#
# Mumbai, India → Melaka, Malaysia → Batam, Indonesia → Darwin, Australia
#   Cables: SeaMeWe-4 → Batam Dumai Melaka (BDM) → Hawaiki Nui 1
#
# Mumbai, India → Songkhla, Thailand → Batam, Indonesia → Darwin, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → Thailand-Indonesia-Singapore (TIS) → Hawaiki Nui 1
#
# Mumbai, India → Tuas, Singapore → Manado, Indonesia → Darwin, Australia
#   Cables: SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Asia Connect Cable-1 (ACC-1)
#
# Mumbai, India → Vung Tau, Vietnam → Tanjung Bemban, Indonesia → Darwin, Australia
#   Cables: Asia Africa Europe-1 (AAE-1) → Asia-America Gateway (AAG) Cable System → Hawaiki Nui 1
#
# Mumbai, India → Melaka, Malaysia → Tanjung Pinggir, Indonesia → Darwin, Australia
#   Cables: SeaMeWe-4 → Batam Dumai Melaka (BDM) → Hawaiki Nui 1
#
# Mumbai, India → Songkhla, Thailand →
Australia
#   Cables: SeaMeWe-4 → Indonesia Global Gateway (IGG) System → INDIGO-West
#
# Chennai, India → Jakarta, Indonesia → Tanah Merah, Singapore → Perth, Australia
#   Cables: ICE IV → Jakarta-Bangka-Bintan-Batam-Singapore (B3JS) → Australia-Singapore Cable (ASC)
#
# Chennai, India → Morib, Malaysia → Tuas, Singapore → Perth, Australia
#   Cables: MIST → MIST → INDIGO-West
#
# Chennai, India → Jakarta, Indonesia → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Chennai, India → Singapore, Singapore → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Chennai, India → Ancol, Indonesia → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Chennai, India → Jakarta, Indonesia → Port Moresby, Papua New Guinea → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Chennai, India → Singapore, Singapore → Batam, Indonesia → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Chennai, India → Tuas, Singapore → Batam, Indonesia → Alexandria, Australia
#   Cables: SeaMeWe-4 → Indonesia Global Gateway (IGG) System → Hawaiki Nui 1
#
# Chennai, India → Ancol, Indonesia → Port Moresby, Papua New Guinea → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Chennai, India → Jakarta, Indonesia → Honiara, Solomon Islands → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Chennai, India → Singapore, Singapore → Port Moresby, Papua New Guinea → Alexandria, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Chennai, India → Changi North, Singapore → Batam, Indonesia → Alexandria, Australia
#   Cables: Tata TGN-Tata Indicom → Thailand-Indonesia-Singapore (TIS) → Hawaiki Nui 1
#
# Chennai, India → Jakarta, Indonesia → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Chennai, India → Singapore, Singapore → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Chennai, India → Ancol, Indonesia → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Chennai, India → Jakarta, Indonesia → Davao, Philippines → Darwin, Australia
#   Cables: ICE IV → Bifrost → Asia Connect Cable-1 (ACC-1)
#
# Chennai, India → Singapore, Singapore → Batam, Indonesia → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Chennai, India → Tuas, Singapore → Tanjung Bemban, Indonesia → Darwin, Australia
#   Cables: SeaMeWe-4 → Apricot → Hawaiki Nui 1
#
# Chennai, India → Ancol, Indonesia → Davao, Philippines → Darwin, Australia
#   Cables: ICE IV → Bifrost → Asia Connect Cable-1 (ACC-1)
#
# Chennai, India → Jakarta, Indonesia → Singapore, Singapore → Darwin, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Chennai, India → Singapore, Singapore → Makassar, Indonesia → Darwin, Australia
#   Cables: ICE IV → Asia Connect Cable-1 (ACC-1) → Asia Connect Cable-1 (ACC-1)
#
# Chennai, India → Changi North, Singapore → Tanjung Bemban, Indonesia → Darwin, Australia
#   Cables: Tata TGN-Tata Indicom → JAKABARE → Hawaiki Nui 1
#
# Chennai, India → Jakarta, Indonesia → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Chennai, India → Singapore, Singapore → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Chennai, India → Ancol, Indonesia → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1
#
# Chennai, India → Jakarta, Indonesia → Port Moresby, Papua New Guinea → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Chennai, India → Singapore, Singapore → Batam, Indonesia → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Hawaiki Nui 1
#
# Chennai, India → Tuas, Singapore → Tanjung Bemban, Indonesia → Paddington, Australia
#   Cables: SeaMeWe-4 → Apricot → Hawaiki Nui 1
#
# Chennai, India → Ancol, Indonesia → Port Moresby, Papua New Guinea → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Chennai, India → Jakarta, Indonesia → Honiara, Solomon Islands → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Chennai, India → Singapore, Singapore → Port Moresby, Papua New Guinea → Paddington, Australia
#   Cables: ICE IV → Hawaiki Nui 1 → Coral Sea Cable System (CS²)
#
# Chennai, India → Changi North, Singapore → Tanjung Bemban, Indonesia → Paddington, Australia
#   Cables: Tata TGN-Tata Indicom → JAKABARE → Hawaiki Nui 1

# %%
# node_coords = {} 
# india_nodes = set()
# australia_nodes = set()
print(allowed_nodes)
# Out:
# {'Natuna, Indonesia', 'Batangas, Philippines', 'Bintulu, Malaysia', 'Naga, Philippines', 'Leganes, Philippines', 'Sangatta, Indonesia', 'Wewak, Papua New Guinea', 'Surigao City, Philippines', 'Singapore, Singapore', 'Lingga, Indonesia', 'Ketapang, Indonesia', 'Kawinda Nae, Indonesia', 'Seraya, Indonesia', 'Padang, Indonesia', 'Inverloch, Australia', 'Thanlyin, Myanmar', 'San Jose, Philippines', 'Agats, Indonesia', 'Roxas City, Philippines', 'Taytay, Philippines', 'Masbate City, Philippines', 'Kalpeni, India', 'Quy Nhon, Vietnam', 'Santa Magdalena, Philippines', 'Liloy, Philippines', 'Dili, Timor-Leste', 'Raha, Indonesia', 'Bulan, Philippines', 'Ambon, Indonesia', 'Kampung Raja, Malaysia', 'Claveria, Philippines', 'Kuala Sedili, Malaysia', 'Tanjung Bemban, Indonesia', 'Butuan City, Philippines', 'Ancol, Indonesia', 'Coron, Philippines', 'Saraemee, Indonesia', 'Popondetta, Papua New Guinea', 'Tanjung Selor, Indonesia', 'Kavieng, Papua New Guinea', 'Buranga, Indonesia', 'Alyangula, Australia', 'Colombo, Sri Lanka', 'Cadiz City, Philippines', 'Perth, Australia', 'Mersing, Malaysia', 'Serwaru, Indonesia', 'Chumphon, Thailand', 'Kep. Aru, Indonesia', 'Allen, Philippines', 'Toledo, Philippines', 'Bima, Indonesia', 'Sangata, Indonesia', 'Kiamsam, Malaysia', 'Palompon, Philippines', 'Gianyar, Indonesia', 'Maroubra, Australia', 'Rengit, Malaysia', 'Ranai, Indonesia', 'Puger, Indonesia', 'Lorengau, Papua New Guinea', 'Car Nicobar, India', 'Sorong, Indonesia', 'Kikori, Papua New Guinea', 'Pankalan, Indonesia', 'Morowali, Indonesia', 'Telisai, Brunei', 'Sungsang, Indonesia', 'Dumaguete, Philippines', 'Labuan Bajo, Indonesia', 'Tungku, Brunei', 'Ujung Pankah, Indonesia', 'Torquay, Australia', 'Ozamiz City, Philippines', 'Madura, Indonesia', 'Zamboanguita, Philippines', 'Fakfak, Indonesia', 'Kaimana, Indonesia', 'Phetchaburi, Thailand', 'Daanbantayan, Philippines', 'Camiguin Island, Philippines', 'Vanimo, Papua New Guinea', 'McGaurans Beach, Australia', 'Masohi, Indonesia', 'Gresik, Indonesia', 'Rayong, Thailand', 'Towale, Indonesia', 'Cirebon, Indonesia', 'Daet, Philippines', 'Tua Pejat, Indonesia', 'Tuticorine, India', 'Sydney, Australia', 'Boac, Philippines', 'San Jose de Buenavista, Philippines', 'Bauang, Philippines', 'La Union, Philippines', 'Morotai, Indonesia', 'Cebu, Philippines', 'Kadmat, India', 'Luna, Philippines', 'Lakudo, Indonesia', 'Batu Prahu, Indonesia', 'Four Mile Bluff, Australia', 'Tiakur, Indonesia', 'Great Nicobar, India', 'Kokar, Indonesia', 'Mentigi, Indonesia', 'Candikusuma, Indonesia', 'San Juan, Philippines', 'Bengkalis, Indonesia', 'Penarik, Indonesia', 'Madang, Papua New Guinea', 'Supiori, Indonesia', 'Buenavista, Philippines', 'Milagros, Philippines', 'Kuching, Malaysia', 'Alexandria, Australia', 'Lae, Papua New Guinea', 'Agatti, India', 'Caticlan, Philippines', 'Bitra, India', 'Alotau, Papua New Guinea', 'Tanjung Pakis, Indonesia', 'Tanah Merah, Singapore', 'Legazpi City, Philippines', 'Tanjung Pinggir, Indonesia', 'Pinamalayan, Philippines', 'Baubau, Indonesia', 'Pulau Perhentian Besar, Malaysia', 'Talisay City, Philippines', 'Sriracha, Thailand', 'Denpasar, Indonesia', 'Changi North, Singapore', 'Luwuk, Indonesia', 'Minicoy, India', 'Ballesteros, Philippines', 'Bulobulo, Indonesia', 'Daru, Papua New Guinea', 'Bawean, Indonesia', 'Taliabu, Indonesia', 'Kerema, Papua New Guinea', 'Lumut, Malaysia', 'Yapen, Indonesia', 'Singkawang, Indonesia', 'PIK2, Indonesia', 'Calatrava, Philippines', 'Mataram, Indonesia', 'Bandar Lampung, Indonesia', 'Darwin, Australia', 'Kendal, Indonesia', 'Kota Mappi, Indonesia', 'Suemlaki, Indonesia', 'Little Andaman, India', 'Boracay, Philippines', 'Surabaya, Indonesia', 'Tobelo, Indonesia', 'Nongsa, Indonesia', 'Kingscote, Australia', 'Wurrumiyanga, Australia', 'Paddington, Australia', 'Kokopo, Papua New Guinea', 'Muntok, Indonesia', 'Davao, Philippines', 'Ondong Siau, Indonesia', 'Sanana, Indonesia', 'Kamorta, India', 'Pulau Perhentian Kecil, Malaysia', 'Teluk, Indonesia', 'Lombok, I ...

# %%
print(len(all_valid_paths))
# Out:
# 300
# Requirement already satisfied: folium in c:\users\aadit\anaconda3\envs\pe2\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\aadit\anaconda3\envs\pe2\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\aadit\anaconda3\envs\pe2\lib\site-packages (from folium) (3.1.5)
# Requirement already satisfied: numpy in c:\users\aadit\anaconda3\envs\pe2\lib\site-packages (from folium) (2.0.1)
# Requirement already satisfied: requests in c:\users\aadit\anaconda3\envs\pe2\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\aadit\anaconda3\envs\pe2\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aadit\anaconda3\envs\pe2\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aadit\anaconda3\envs\pe2\lib\site-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aadit\anaconda3\envs\pe2\lib\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aadit\anaconda3\envs\pe2\lib\site-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aadit\anaconda3\envs\pe2\lib\site-packages (from requests->folium) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

with open("india_australia_paths.geojson") as f:
    geojson_data = json.load(f)

m = folium.Map(location=[-10, 100], zoom_start=4, tiles="cartodb positron")

for feature in geojson_data["features"]:
    coords = feature["geometry"]["coordinates"]
    cables = feature["properties"]["cables"]
    path = feature["properties"]["path"]

    folium.PolyLine(
        locations=[(lat, lon) for lon, lat in coords], 
        color="blue",
        weight=3,
        opacity=0.7,
        tooltip=" → ".join(cables)
    ).add_to(m)

    start = coords[0]
    end = coords[-1]
    folium.Marker(
        location=(start[1], start[0]),
        popup=f"Start: {path[0]}",
        icon=folium.Icon(color="green", icon="play")
    ).add_to(m)
    folium.Marker(
        location=(end[1], end[0]),
        popup=f"End: {path[-1]}",
        icon=folium.Icon(color="red", icon="stop")
    ).add_to(m)

m.save("india_australia_paths_map.html")
# print("Map saved to india_australia_paths_map.html")
